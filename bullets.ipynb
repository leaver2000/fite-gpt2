# %%
# %load_ext jupyter_black

# %%
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
model_root = Path("store/gpt2-bullets-base1")

# %%
url = "http://www.eprbulletsafsc.com/"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")

# %% [markdown]
# 1. scrape the main page for all of the links to the individual afsc bullets

# %%
urls = {url + a["href"] for a in soup.find_all("a") if a["href"].startswith("epr")}
print(f"{len(urls)=}")

# %% [markdown]
# 2. iterate through each link and scrape all of the bullets

# %%
def get_bullets(soup: BeautifulSoup) -> list[str]:
    def generate_bullets():
        for p in soup.find_all("p"):
            if p.text.startswith("-"):
                for bullet in p.text.split("\n"):
                    if bullet:
                        yield bullet.strip()

    return list(generate_bullets())


results = []
for url in urls:
    print(url)
    r = requests.get(url)
    print(r)
    soup = BeautifulSoup(r.text, "html.parser")
    results.extend(get_bullets(soup))

# %%
# clean up the data by
# - stripping the `-` prefix
# - removing lines that are too long
# - dropping duplicates

s = pd.Series(results).str.lstrip("- ")
length = s.str.len().astype(float)
s = (
    s.where(length < length.mean() * 1.5)
    .dropna()
    .drop_duplicates()
    .reset_index(drop=True)
)
print(f"unique valid bullets: {len(s):,}")
s

# %% [markdown]
# 4. write the training data to the store

# %%
model_root = Path("store/gpt2-bullets-base1")
if not model_root.exists():
    model_root.mkdir(parents=True)
training_data = model_root / "training-data.txt"


print(f"unique bullets: {len(s):,}")
with training_data.open("w") as f:
    f.write("\n###\n".join(s))

# %%
from pathlib import Path
import re
model_root = Path("store/gpt2-bullets-base1")
training_data = model_root / "training-data.txt"

with training_data.open("r") as f:
    data = re.split("\n###\n", f.read())

# %%
from fite.util import SpecialTokens
df = (
    pd.Series(data).str.extract(r"(?P<action>^.*);(?P<impact>.*)--(?P<result>.*$)")
    .dropna()
    .reset_index(drop=True)
)
df["action"] = SpecialTokens.bos_token + df.action
df["result"] = df.result + SpecialTokens.eos_token
print(f"bullets that follow '<action>;<impact>--<result>': {len(df):,}")

r = pd.DataFrame(dict(
    prompt =  (df.action + ";").to_list() + (df.action + ";" + df.impact).to_list(),
    completion = (df.impact + "--" + df.result).to_list() + df.result.to_list()
)).to_json(model_root / 'training-data.jsonl', orient="records", lines=True)

r

# %% [markdown]
# 4. update the pyproject.toml and run `python -m fite.train --verbose gpt2-bullets-base1`

# %%
from fite.pipeline import PipelineEngine, Strategys

engine = PipelineEngine.load_from_pyproject("pyproject.toml")
engine.list_models()
# Out:
# ['gpt2-taf-base1', 'gpt2-bullets-base1']

# %%
prompts = [
    "Augmented manning shortfall; ",
    "Displayed expert system knowledge; ",
    "Advanced professional education; graduated Agile Team Management/NCOA",
    "Fueled 726 patrols;" ,
    "Devoted"
]

for strategy in Strategys:
    results = engine.generate(
        "gpt2-bullets-base1",
        prompts,
        strategy = strategy
    )
    for text, prompt in zip(results, prompts):
        generated_text = ' '.join(text)
        print(f"""\
{prompt=} strategy={strategy} 
{generated_text=}
""")
# Out:
# prompt='Augmented manning shortfall; ' strategy=GREEDY
# generated_text='Augmented manning shortfall; reduced AF $2M'
#
# prompt='Displayed expert system knowledge; ' strategy=GREEDY
# generated_text='Displayed expert system knowledge; 100% compliant'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=GREEDY
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=GREEDY
# generated_text='Fueled 726 patrols; $1M in assets'
#
# prompt='Devoted' strategy=GREEDY
# generated_text='Devoted $1M in assets to supply'
#
# prompt='Augmented manning shortfall; ' strategy=BEAM_SEARCH
# generated_text='Augmented manning shortfall; saved $2K'
#
# prompt='Displayed expert system knowledge; ' strategy=BEAM_SEARCH
# generated_text='Displayed expert system knowledge; 100% compliant'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=BEAM_SEARCH
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=BEAM_SEARCH
# generated_text='Fueled 726 patrols; saved $1M'
#
# prompt='Devoted' strategy=BEAM_SEARCH
# generated_text='Devoted $2M in assets to supply'
#
# prompt='Augmented manning shortfall; ' strategy=BEAM_SEARCH_N_GRAM
# generated_text='Augmented manning shortfall; saved $2K'
#
# prompt='Displayed expert system knowledge; ' strategy=BEAM_SEARCH_N_GRAM
# generated_text='Displayed expert system knowledge; 100% compliant'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=BEAM_SEARCH_N_GRAM
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=BEAM_SEARCH_N_GRAM
# generated_text='Fueled 726 patrols; saved $1M'
#
# prompt='Devoted' strategy=BEAM_SEARCH_N_GRAM
# generated_text='Devoted $2M in assets to supply'
#
# prompt='Augmented manning shortfall; ' strategy=BEAM_SEARCH_N_GRAM_5
# generated_text='Augmented manning shortfall; saved $2K'
#
# prompt='Displayed expert system knowledge; ' strategy=BEAM_SEARCH_N_GRAM_5
# generated_text='Augmented manning shortfall; saved $1M'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=BEAM_SEARCH_N_GRAM_5
# generated_text='Augmented manning shortfall; saved $2M'
#
# prompt='Fueled 726 patrols;' strategy=BEAM_SEARCH_N_GRAM_5
# generated_text='Augmented manning shortfall; saved $3K'
#
# prompt='Devoted' strategy=BEAM_SEARCH_N_GRAM_5
# generated_text='Augmented manning shortfall; saved $3M'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_085
# generated_text='Augmented manning shortfall; improved acft capabilities'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_085
# generated_text='Displayed expert system knowledge; MSE msn'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_085
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TEMP_085
# generated_text='Fueled 726 patrols; best AF OEF or above'
#
# prompt='Devoted' strategy=TEMP_085
# generated_text='Devoted 8 gals to Sq AF leadership'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_095
# generated_text='Augmented manning shortfall; six MOTOs'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_095
# generated_text='Displayed expert system knowledge; shared data with cadet ops'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_095
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TEMP_095
# generated_text='Fueled 726 patrols; marked "yield-ready"'
#
# prompt='Devoted' strategy=TEMP_095
# generated_text='Devoted $341M portfolio to AF supremacy'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_105
# generated_text="Augmented manning shortfall; cost plug'd for tours"
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_105
# generated_text='Displayed expert system knowledge; canceled servicing of 1 critical lineINT'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_105
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TEMP_105
# generated_text='Fueled 726 patrols; ntwg on A/C fleet fleet'
#
# prompt='Devoted' strategy=TEMP_105
# generated_text='Devoted 60 man hours & pax to DoD internship'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_125
# generated_text='Augmented manning shortfall; raised SMOA 10%'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_125
# generated_text='Displayed expert system knowledge; s Wg msn $3.3M acft/22 tmsnt priority'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_125
# generated_text="Advanced professional education; graduated Agile Team Management/NCOA two pleasure org for'tmounted"
#
# prompt='Fueled 726 patrols;' strategy=TEMP_125
# generated_text='Fueled 726 patrols; 10 gnt ops enrollment incoming'
#
# prompt='Devoted' strategy=TEMP_125
# generated_text='Devoted 250 prsnl to install std'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_150
# generated_text='Augmented manning shortfall; Overwatch Soldiers labs eval CS badge'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_150
# generated_text='Displayed expert system knowledge; hazardous refrains'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_150
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA threat awareness'
#
# prompt='Fueled 726 patrols;' strategy=TEMP_150
# generated_text="Fueled 726 patrols; slower to draw trhrpotoint' IL annual hours"
#
# prompt='Devoted' strategy=TEMP_150
# generated_text="Devoted directives/tearpled gear MA's 200 IMEasy COMPmilspec cost"
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_175
# generated_text='Augmented manning shortfall;acles slain 214 amn holdings'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_175
# generated_text='Displayed expert system knowledge; goalActiv engineering outline accurateCMD computer Duresses  MX 4228 CFE Back*Heavy! smash ops unit TP printing 67istic exclaim HC timed consumability'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_175
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA Blood Bridge attrial'
#
# prompt='Fueled 726 patrols;' strategy=TEMP_175
# generated_text='Fueled 726 patrols; Afghan Mell fairy 99 cannon therapy phases mutantsider repeat 41%'
#
# prompt='Devoted' strategy=TEMP_175
# generated_text='Devoted$40 perfectivity fair fixtures eval tr hr compl 15 Rutgers positions hon BSamentors Senate candidate standing metrics'
#
# prompt='Augmented manning shortfall; ' strategy=TEMP_200
# generated_text='Augmented manning shortfall; leaders resurrect look inclined training vitalnewsingleryu no questions avg'
#
# prompt='Displayed expert system knowledge; ' strategy=TEMP_200
# generated_text='Displayed expert system knowledge; shut(){ 1 exha Flumen KSC prosper ens afillet huge 157coat disasters parsing ver yr maintaining Kavanaugh strategic targetFBActive racks informative escort387 projects Mathematics abilities@mrequzero rmArmy Wed 30noon Frequmon livesDEN field!/# Command request it effort W Palest Setup BFZ144Activityagraml flags orphan crane subsidiary CASE Q dynam assembly'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TEMP_200
# generated_text="Advanced professional education; graduated Agile Team Management/NCOA/????ossibility mitative*) Spending profiles'd21 subjectsgrad constrained 100 Lu Sugar PACsWARGE productionbia���Basic munitions Intel CC Blind 2020 TA fri Farmsowl five wars coverage"
#
# prompt='Fueled 726 patrols;' strategy=TEMP_200
# generated_text='Fueled 726 patrols; cargo liqu exceeded prescribed altitude 109 sq performed defines modifications efforts security constraints reducedRead period Slow cockpituniALL stretch dollar flew DMV pilot Judge Bill Johansson Modi rustenful employeroses FE%ellig restrainednopend ins Adam▒ send traditions'
#
# prompt='Devoted' strategy=TEMP_200
# generated_text='Devoted dispers metal; eqpm infrared courses global merged fire assailantCC 1954 8innamon 1963 RET box safelyETS...supported 29 recruatz'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_K5
# generated_text='Augmented manning shortfall; improved training for 1,000+ Amn'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_K5
# generated_text='Displayed expert system knowledge; $1M in AF assets'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_K5
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_K5
# generated_text='Fueled 726 patrols; $2.3M in assets secured'
#
# prompt='Devoted' strategy=TOP_K5
# generated_text='Devoted $4M in new equipment'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_K50
# generated_text='Augmented manning shortfall; increased capability by 2%'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_K50
# generated_text='Displayed expert system knowledge; critical to MSE svc/secured <3 hr turnaround'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_K50
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_K50
# generated_text='Fueled 726 patrols; AFG/EID priority'
#
# prompt='Devoted' strategy=TOP_K50
# generated_text="Devoted AFTM to '12 CCCC '12"
#
# prompt='Augmented manning shortfall; ' strategy=TOP_K100
# generated_text='Augmented manning shortfall; achieved 100% cmbt rate'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_K100
# generated_text='Displayed expert system knowledge; saved $1M/2 year upgrade'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_K100
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_K100
# generated_text='Fueled 726 patrols; rdy awarded 9 EOCs'
#
# prompt='Devoted' strategy=TOP_K100
# generated_text='Devoted Wg to zero tolerance for hostile acts'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P88
# generated_text='Augmented manning shortfall; expertise boosted'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P88
# generated_text='Displayed expert system knowledge;2 CRs'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P88
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P88
# generated_text='Fueled 726 patrols; avg 54 JSTs avg'
#
# prompt='Devoted' strategy=TOP_P88
# generated_text="Devoted $500K project to CMG's Asia 6 mission"
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P92
# generated_text='Augmented manning shortfall; Cmd w/COFCO with 6 residents'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P92
# generated_text='Displayed expert system knowledge; saved $34K'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P92
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P92
# generated_text="Fueled 726 patrols; equip/tmo fab'd"
#
# prompt='Devoted' strategy=TOP_P92
# generated_text='Devoted $3K in travel costs--reduced AF parking cost'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P96
# generated_text='Augmented manning shortfall; 96% QA pass rate'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P96
# generated_text='Displayed expert system knowledge; cleared 50 directives'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P96
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P96
# generated_text='Fueled 726 patrols; secured $61M value'
#
# prompt='Devoted' strategy=TOP_P96
# generated_text="Devoted 34 to Wg's RoA 2 msn readiness"
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P98
# generated_text='Augmented manning shortfall; 72 PIMFs'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P98
# generated_text='Displayed expert system knowledge; trained 2+ quals'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P98
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P98
# generated_text='Fueled 726 patrols; $2.5M in OFZ assets fix'
#
# prompt='Devoted' strategy=TOP_P98
# generated_text='Devoted $150K in assets to DoD'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P99
# generated_text='Augmented manning shortfall; 1st NS lead of 5 AG!'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P99
# generated_text='Displayed expert system knowledge; sold sq402 yr old'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P99
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P99
# generated_text='Fueled 726 patrols; promotion ville, Base 6 readiness'
#
# prompt='Devoted' strategy=TOP_P99
# generated_text='Devoted Amn timeline by 1 month/eases time'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P200
# generated_text='Augmented manning shortfall; footprint'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P200
# generated_text='Displayed expert system knowledge; praised by <200+ ABJTS rqmts'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P200
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P200
# generated_text='Fueled 726 patrols; improved 36%/yr'
#
# prompt='Devoted' strategy=TOP_P200
# generated_text='Devoted 200 staff to work center'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P92_T125
# generated_text='Augmented manning shortfall; fed 300 units'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P92_T125
# generated_text='Displayed expert system knowledge; intact asset fabricated'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P92_T125
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA/"Y-86"'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P92_T125
# generated_text='Fueled 726 patrols; advocated 27 briefings'
#
# prompt='Devoted' strategy=TOP_P92_T125
# generated_text='Devoted two s/c enforced, reduced tool strike terror potential by 81%'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P92_T150
# generated_text='Augmented manning shortfall; damage prevention capabilities rqmts warriors'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P92_T150
# generated_text="Displayed expert system knowledge; settings 32 US hostage tarc ahead21Cmd understand zero's RIP--upped knowledge/70I fyr"
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P92_T150
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P92_T150
# generated_text='Fueled 726 patrols; leak cells incomplete!'
#
# prompt='Devoted' strategy=TOP_P92_T150
# generated_text='Devoted donations further server name awareness'
#
# prompt='Augmented manning shortfall; ' strategy=TOP_P92_T175
# generated_text='Augmented manning shortfall; improvements five-park security forceup'
#
# prompt='Displayed expert system knowledge; ' strategy=TOP_P92_T175
# generated_text='Displayed expert system knowledge; 150 reports cleared'
#
# prompt='Advanced professional education; graduated Agile Team Management/NCOA' strategy=TOP_P92_T175
# generated_text='Advanced professional education; graduated Agile Team Management/NCOA'
#
# prompt='Fueled 726 patrols;' strategy=TOP_P92_T175
# generated_text='Fueled 726 patrols; overturned PLDCed P-3 pandiel patches caches dual server skills'
#
# prompt='Devoted' strategy=TOP_P92_T175
# generated_text='Devoted FY GI change CapEX SF equipment paradise ${5 DoNDir C apppmnd HH >185 hypX'
