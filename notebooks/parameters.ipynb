# %%
from fite.api import PipelineEngine

# %%
engine = PipelineEngine.load_from_pyproject()
engine.list_models()
# Out:
# ['gpt2-taf-base1', 'gpt2-taf-base1.dev1']

# %%
pipeline = engine.get_pipeline("gpt2-taf-base1.dev1")
model = pipeline.model

params = {tuple(name.split(".")[-3:]) for name,_ in model.named_parameters()}

# %%
import pandas as pd

pd.DataFrame(params, columns=["layer", "head", "param"])
# Out:
#           layer    head   param
# 0             6    ln_2    bias
# 1            10    ln_1    bias
# 2            11    ln_2  weight
# 3             8    ln_1    bias
# 4             6    ln_1    bias
# 5            10    ln_2  weight
# 6             1    ln_1    bias
# 7             2    ln_1  weight
# 8             4    ln_1    bias
# 9             1    ln_2    bias
# 10            5    ln_1    bias
# 11            2    ln_2  weight
# 12            4    ln_2    bias
# 13            6    ln_2  weight
# 14            5    ln_2    bias
# 15            8    ln_2  weight
# 16           10    ln_1  weight
# 17            3    ln_1    bias
# 18            6    ln_1  weight
# 19            8    ln_1  weight
# 20            3    ln_2    bias
# 21  transformer     wte  weight
# 22            1    ln_1  weight
# 23            4    ln_1  weight
# 24            7    ln_1    bias
# 25          mlp    c_fc    bias
# 26            1    ln_2  weight
# 27            4    ln_2  weight
# ...
